# %% [markdown]
# <a href="https://colab.research.google.com/github/student-data-science/5_Lesson-4-Matplotlib-seaborn.-SQL.-Flask-/blob/main/%D0%97%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B55_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('data.csv.1', sep=',', parse_dates=True, index_col=0)
df.plot()
plt.show()
